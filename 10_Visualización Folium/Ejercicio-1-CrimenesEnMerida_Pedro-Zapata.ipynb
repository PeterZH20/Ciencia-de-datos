# %% [markdown]
#
# La Fiscalía General del Estado informó que al día en promedio en Yucatán se registran ocho robos en sus diferentes modalidades, aunque la mayor parte de ellos, cerca del 80 por ciento, ocurre en Mérida.
#
# En esta ciudad, las zonas de mayor incidencia son el Poniente, Sur y Centro.
#
# Aunque los casos más sonados, de mayor cuantía en cuanto al botín y que han llamado la atención de los medios, se dijo que se han registrado en el Norte.
#
# https://www.yucatan.com.mx/merida/merida-el-blanco-principal-de-los-robos
#
#  <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# <div class="alert alert-success">
#
# Con los datos del archivo "asaltos_yucatan.csv", mostrar en un mapa la ubicación de los delitos en Mérida, de ser posible muestre como _popup_ la categoría.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
#Cargar el archivo datos/asaltos_yucatan.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
df = pd.read_csv('datos/asaltos_yucatan.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
df.head()
# Out:
#    NumInc  Categoria              Descripcion   Ciudad          Direccion  \
# 0       1     asalto  robo objetos personales  Tizimín             Centro
# 1       2     asalto  robo objetos personales   Mérida         Calle 53-F
# 2       3     asalto  robo objetos personales   Mérida   Calle 53 791-803
# 3       4     asalto  robo objetos personales   Mérida   Calle 49 808-796
# 4       5  robo casa     robo casa habitacion   Mérida  Calle 51A 784-780
#
#          lat       long
# 0  21.142586 -88.147633
# 1  21.074071 -89.666229
# 2  21.077830 -89.655865
# 3  21.001845 -89.713986
# 4  21.000559 -89.712173

# %%
df.shape
# Out:
# (28, 7)

# %%
ubi=[]
cat=[]
for i in range(len(df)):
    ubi.append(df.iloc[i,5:].tolist())
    cat.append(df.iloc[i,1])
print(ubi)
print(cat)
# Out:
# [[21.142586, -88.147633], [21.074071, -89.666229], [21.07783, -89.655865], [21.001845, -89.713986], [21.000559, -89.712173], [20.998856, -89.724501], [20.993177, -89.711294], [20.971428, -89.639831], [20.963172, -89.631224], [20.961709, -89.629484], [20.962226, -89.625623], [20.966332, -89.622564], [20.965547, -89.624648], [20.964993, -89.621685], [20.962066, -89.621226], [20.965154, -89.622679], [20.993106, -89.660014], [21.011345, -89.653112], [21.036359, -89.648149], [21.024048, -89.583452], [20.937102, -89.617097], [20.934667, -89.627341], [20.925104, -89.647423], [20.924396, -89.611624], [20.925407, -89.611841], [21.278883, -89.673298], [21.280883, -89.65802], [21.284122, -89.665359]]
# ['asalto', 'asalto', 'asalto', 'asalto', 'robo casa', 'asalto', 'asalto', 'asalto', 'asalto', 'asalto', 'asalto', 'robo casa', 'asalto', 'asalto', 'asalto', 'asalto', 'asalto', 'asalto', 'robo casa', 'robo casa', 'asalto', 'robo casa', 'asalto', 'asalto', 'asalto', 'asalto', 'asalto', 'asalto']

# %%
cat[0]
# Out:
# 'asalto'

# %%
mapa = folium.Map(location=[20.97537, -89.61696],zoom_start=7,min_zoom=5,max_zoom=20)
for i in range(len(df)):
    folium.Marker(location=ubi[i],popup=cat[i],icon=folium.Icon(color='red',prefix='fa',icon="circle-exclamation")).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5c6126bfcbe56e52d3c0074bce18c41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5c6126bfcbe56e52d3c0074bce18c41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5c6126bfcbe56e52d3c0074bce18c41 = L.map(
#                 &quot;map_c5c6126bfcbe56e52d3c0074bce18c41&quot;,
#                 {
#                     center: [20.97537, -89.61696],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2ff7354bfd7899e8aa1488806c78a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 5, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c5c6126bfcbe56e52d3c0074bce18c41);
#
#
#             var marker_7a56e727cade4a8cceda0a865f2fcfa4 = L.marker(
#                 [21.142586, -88.147633],
#                 {}
#             ).addTo(map_c5c6126bfcbe56e52d3c0074bce18c41);
#
#
#             var icon_08ad1433091d717ded8a80f690e1a2f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle-exclamation&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7a56e727cade4a8cceda0a865f2fcfa4.setIcon(icon_08ad1433091d717ded8a80f690e1a2f9);
#
#
#         var popup_27626d4bb7ddcc5e575e6bbe0f5a23af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5c339be0126acffb23efb2992b22e37 = $(`&lt;div id=&quot;html_f5c339be0126acffb23efb2992b22e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;asalto&lt;/div&gt;`)[0];
#                 popup_27626d4bb7ddcc5e575e6bbe0f5a23af.setContent(html_f5c339be0126acffb23efb2992b22e37);
#
#
#
#         marker_7a56e727cade4a8cceda0a865f2fcfa4.bindPopup(popup_27626d4bb7ddcc5e575e6bbe0f5a23af)
#         ;
#
#
#
#
#             var marker_1867f0b88a549d6b959e2fff201c58b3 = L.marker(
#                 [21.074071, -89.666229],
#                 {}
#             ).addTo(map_c5c6126bfcbe56e52d3c0074bce18c41);
#
#
#             var icon_df8edf4660824c8476b613daa495a236 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle-exclamation&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1867f0b88a549d6b959e2fff201c58b3.setIcon(icon_df8edf4660824c8476b613daa495a236);
#
#
#         var popup_55e3ad9691a205a866df8b40e0945313 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c283dd469609ded2a3f3ad24252b91f = $(`&lt;div id=&quot;html_1c283dd469609ded2a3f3ad24252b91f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;asalto&lt;/div&gt;`)[0];
#                 popup_55e3ad9691a205a866df8b40e0945313.setContent(html_1c283dd469609ded2a3f3ad24252b91f);
#
#
#
#         marker_1867f0b88a549d6b959e2fff201c58b3.bindPopup(popup_55e3ad9691a205a866df8b40e0945313)
#         ;
#
#
#
#
#             var marker_9a1a3e94e41ff4af13a3dda2b052b6b7 = L.marker(
#                 [21.07783, -89.655865],
#                 {}
#             ).addTo(map_c5c6126bfcbe56e52d3c0074bce18c41);
#
#
#             var icon_22219ed778dd85d55f5d9dc0d36ba63f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle-exclamation&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9a1a3e94e41ff4af13a3dda2b052b6b7.setIcon(icon_22219ed778dd85d55f5d9dc0d36ba63f);
#
#
#         var popup_794057eb55fa8c1107e49d000605878d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6e1707284804a3237dcefaa0077c510 = $(`&lt;div id=&quot;html_e6e1707284804a3237dcefaa0077c510&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;asalto&lt;/div&gt;`)[0];
#                 popup_794057eb55fa8c1107e49d000605878d.setContent(html_e6e1707284804a3237dcefaa0077c510);
#
#
#
#         marker_9a1a3e94e41ff4af13a3dda2b052b6b7.bindPopup(popup_794057eb55fa8c1107e49d000605878d)
#         ;
#
#
#
#
#             var marker_d47f912d5edd971022050d6a04915aac = L.marker(
#                 [21.001845, -89.713986],
#                 {}
#             ).addTo(map_c5c6126bfcbe56e52d3c0074bce18c41);
#
#
#             var icon_715278dc216aa0609413522773538db0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle-exclamation&
